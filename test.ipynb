# %%
import pandas as pd
from sklearn import ensemble
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('data/train.csv')
X_train, y_train = df.iloc[:,:-1], df.iloc[:,-1]
print(y_train[y_train==1].count())
print(y_train[y_train==0].count())
X_train
# Out:
# 7108
# 25891
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 32994        35.0          male      High School        87428.0
# 32995        26.0        female         Bachelor        91318.0
# 32996        23.0        female         Bachelor        79749.0
# 32997        25.0          male      High School        51450.0
# 32998        35.0          male         Bachelor        70632.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 32994              10              MORTGAGE    12888.0            MEDICAL
# 32995               6              MORTGAGE     8000.0            VENTURE
# 32996               0                  RENT    16800.0           PERSONAL
# 32997               1                  RENT     6000.0            MEDICAL
# 32998              12                  RENT     7500.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 32994           6.47                 0.15                         7.0
# 32995          14.92                 0.09                         5.0
# 32996          11.28                 0.21                         2.0
# 32997          12.48                 0.12                         3.0
# 32998          11.61                 0.11                        14.0
#
#        credit_score previous_loan_defaults_on_file
# 0               561                             No
# 1               504                            Yes
# 2               635                             No
# 3               675                             No
# 4               586                             No
# ...             ...                            ...
# 32994           664                            Yes
# 32995           590                            Yes
# 32996           632                             No
# 32997           661                             No
# 32998           703                             No
#
# [32999 rows x 13 columns]

# %%
cat_cols = ['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file']

ohe = OneHotEncoder(drop='if_binary')
classifier = ensemble.RandomForestClassifier(n_estimators=200, criterion='entropy')

transformer = ColumnTransformer(
    [('cat_trans', ohe, cat_cols)], 
    remainder='passthrough')
transformer.fit(X_train)

X_train_transformed = transformer.transform(X_train)

# %%
classifier.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
y_train_pred = classifier.predict(X_train_transformed)
print(f'Train Accuracy: {accuracy_score(y_train, y_train_pred)}')
print(f'Train F1: {f1_score(y_train, y_train_pred)}')
print(f'Train Precision: {precision_score(y_train, y_train_pred)}')
print(f'Train Recall: {recall_score(y_train, y_train_pred)}')
# Out:
# Train Accuracy: 1.0
# Train F1: 1.0
# Train Precision: 1.0
# Train Recall: 1.0

# %%
df = pd.read_csv('data/test.csv')

X_test, y_test = transformer.transform(df.iloc[:,:-1]), df.iloc[:,-1]

y_test_pred = classifier.predict(X_test)

print(f'Train Accuracy: {accuracy_score(y_test, y_test_pred)}')
print(f'Test F1: {f1_score(y_test, y_test_pred)}')
print(f'Test Precision: {precision_score(y_test, y_test_pred)}')
print(f'Test Recall: {recall_score(y_test, y_test_pred)}')
# Out:
# Train Accuracy: 0.9301666666666667
# Test F1: 0.8418867924528302
# Test Precision: 0.9264950166112956
# Test Recall: 0.7714384508990318
